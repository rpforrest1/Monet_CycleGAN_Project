# %% [markdown]
# # Monet CycleGAN Model 11

# %%
import warnings

warnings.filterwarnings('ignore')

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from keras import Sequential
from keras.callbacks import ModelCheckpoint
from kaggle_datasets import KaggleDatasets
import matplotlib.pyplot as plt
import numpy as np
import PIL
import shutil
import os

try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
    print('Device:', tpu.master())
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
except:
    strategy = tf.distribute.get_strategy()
print('Number of replicas:', strategy.num_replicas_in_sync)

AUTOTUNE = tf.data.experimental.AUTOTUNE
    
print(tf.__version__)
# Out:
# 2024-03-05 03:24:07.619248: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-05 03:24:07.619342: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-05 03:24:07.757045: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Number of replicas: 1
# 2.15.0

# %%
# Model Tuning Parameters
MODEL_NAME = 'model_11'
LOSS_TYPE = 'bce'
ROTATE_AND_ZOOM = False
EPOCHS = 100

# %% [markdown]
# ---

# %% [markdown]
# ## Load Data and Prep

# %%
GCS_PATH = KaggleDatasets().get_gcs_path()

MONET_FILENAMES = tf.io.gfile.glob(str(GCS_PATH + '/monet_tfrec/*.tfrec'))
print('Monet TFRecord Files:', len(MONET_FILENAMES))

PHOTO_FILENAMES = tf.io.gfile.glob(str(GCS_PATH + '/photo_tfrec/*.tfrec'))
print('Photo TFRecord Files:', len(PHOTO_FILENAMES))
# Out:
# Monet TFRecord Files: 5
# Photo TFRecord Files: 20

# %%
IMAGE_SIZE = [256, 256]

def decode_image(image):
    image = tf.image.decode_jpeg(image, channels=3)
    image = (tf.cast(image, tf.float32) / 127.5) - 1
    image = tf.reshape(image, [*IMAGE_SIZE, 3])
    return image

def read_tfrecord(example):
    tfrecord_format = {
        "image_name": tf.io.FixedLenFeature([], tf.string),
        "image": tf.io.FixedLenFeature([], tf.string),
        "target": tf.io.FixedLenFeature([], tf.string)
    }
    example = tf.io.parse_single_example(example, tfrecord_format)
    image = decode_image(example['image'])
    return image

# %%
def load_dataset(filenames, labeled=True, ordered=False):
    dataset = tf.data.TFRecordDataset(filenames)
    dataset = dataset.map(read_tfrecord, num_parallel_calls=AUTOTUNE)
    return dataset

# %%
monet_ds = load_dataset(MONET_FILENAMES, labeled=True).batch(1).prefetch(buffer_size=AUTOTUNE)
photo_ds = load_dataset(PHOTO_FILENAMES, labeled=True).batch(1).prefetch(buffer_size=AUTOTUNE)
photo_original_ds = load_dataset(PHOTO_FILENAMES, labeled=True).batch(1).prefetch(buffer_size=AUTOTUNE)

# %%
# Data augmentation
if ROTATE_AND_ZOOM:
    data_augmentation = Sequential([
        layers.RandomFlip("horizontal_and_vertical"),
        layers.RandomRotation(factor=0.2, fill_mode='reflect'),
        layers.RandomZoom(height_factor=0.2, fill_mode='reflect')
    ])
    
else:
    data_augmentation = Sequential([
        layers.RandomFlip("horizontal_and_vertical"),
    ])

def apply_augmentation(image):
    image = data_augmentation(image, training=True)
    return image


monet_ds = monet_ds.map(apply_augmentation, num_parallel_calls = AUTOTUNE)
photo_ds = photo_ds.map(apply_augmentation, num_parallel_calls = AUTOTUNE)

# %% [markdown]
# ---

# %% [markdown]
# ## Configure Model Architecture

# %% [markdown]
# ### Generator

# %%
OUTPUT_CHANNELS = 3

def downsample(filters, size, apply_instancenorm=True):
    initializer = tf.random_normal_initializer(0., 0.02)
    gamma_init = keras.initializers.RandomNormal(mean=0.0, stddev=0.02)

    result = keras.Sequential()
    result.add(layers.Conv2D(filters, size, strides=2, padding='same',
                             kernel_initializer=initializer, use_bias=False))

    if apply_instancenorm:
        result.add(keras.layers.GroupNormalization(groups=-1, gamma_initializer=gamma_init))

    result.add(layers.LeakyReLU())

    return result

# %%
def upsample(filters, size, apply_dropout=False):
    initializer = tf.random_normal_initializer(0., 0.02)
    gamma_init = keras.initializers.RandomNormal(mean=0.0, stddev=0.02)

    result = keras.Sequential()
    result.add(layers.Conv2DTranspose(filters, size, strides=2,
                                      padding='same',
                                      kernel_initializer=initializer,
                                      use_bias=False))

    result.add(keras.layers.GroupNormalization(groups=-1, gamma_initializer=gamma_init))

    if apply_dropout:
        result.add(layers.Dropout(0.5))

    result.add(layers.ReLU())

    return result

# %%
def Generator():
    inputs = layers.Input(shape=[256,256,3])

    # bs = batch size
    down_stack = [
        downsample(64, 4, apply_instancenorm=False), # (bs, 128, 128, 64)
        downsample(128, 4), # (bs, 64, 64, 128)
        downsample(256, 4), # (bs, 32, 32, 256)
        downsample(512, 4), # (bs, 16, 16, 512)
        downsample(512, 4), # (bs, 8, 8, 512)
        downsample(512, 4), # (bs, 4, 4, 512)
        downsample(512, 4), # (bs, 2, 2, 512)
        downsample(512, 4), # (bs, 1, 1, 512)
    ]

    up_stack = [
        upsample(512, 4, apply_dropout=True), # (bs, 2, 2, 1024)
        upsample(512, 4, apply_dropout=True), # (bs, 4, 4, 1024)
        upsample(512, 4, apply_dropout=True), # (bs, 8, 8, 1024)
        upsample(512, 4), # (bs, 16, 16, 1024)
        upsample(256, 4), # (bs, 32, 32, 512)
        upsample(128, 4), # (bs, 64, 64, 256)
        upsample(64, 4), # (bs, 128, 128, 128)
    ]

    initializer = tf.random_normal_initializer(0., 0.02)
    last = layers.Conv2DTranspose(OUTPUT_CHANNELS, 4,
                                  strides=2,
                                  padding='same',
                                  kernel_initializer=initializer,
                                  activation='tanh') # (bs, 256, 256, 3)

    x = inputs

    # Downsampling through the model
    skips = []
    for down in down_stack:
        x = down(x)
        skips.append(x)

    skips = reversed(skips[:-1])

    # Upsampling and establishing the skip connections
    for up, skip in zip(up_stack, skips):
        x = up(x)
        x = layers.Concatenate()([x, skip])

    x = last(x)

    return keras.Model(inputs=inputs, outputs=x)

# %% [markdown]
# ### Discriminator

# %%
def Discriminator():
    initializer = tf.random_normal_initializer(0., 0.02)
    gamma_init = keras.initializers.RandomNormal(mean=0.0, stddev=0.02)

    inp = layers.Input(shape=[256, 256, 3], name='input_image')

    x = inp

    down1 = downsample(64, 4, False)(x) # (bs, 128, 128, 64)
    down2 = downsample(128, 4)(down1) # (bs, 64, 64, 128)
    down3 = downsample(256, 4)(down2) # (bs, 32, 32, 256)

    zero_pad1 = layers.ZeroPadding2D()(down3) # (bs, 34, 34, 256)
    conv = layers.Conv2D(512, 4, strides=1,
                         kernel_initializer=initializer,
                         use_bias=False)(zero_pad1) # (bs, 31, 31, 512)

    norm1 = keras.layers.GroupNormalization(groups=-1, gamma_initializer=gamma_init)(conv)

    leaky_relu = layers.LeakyReLU()(norm1)

    zero_pad2 = layers.ZeroPadding2D()(leaky_relu) # (bs, 33, 33, 512)

    last = layers.Conv2D(1, 4, strides=1,
                         kernel_initializer=initializer)(zero_pad2) # (bs, 30, 30, 1)

    return tf.keras.Model(inputs=inp, outputs=last)

# %% [markdown]
# ### Create Models

# %%
with strategy.scope():
    monet_generator = Generator() # transforms photos to Monet-esque paintings
    photo_generator = Generator() # transforms Monet paintings to be more like photos

    monet_discriminator = Discriminator() # differentiates real Monet paintings and generated Monet paintings
    photo_discriminator = Discriminator() # differentiates real photos and generated photos

# %%
print("\033[1mMonet Generator Model Summary:\033[0m")
monet_generator.summary()
# Out:
# Monet Generator Model Summary:
# Model: "functional_17"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_1        │ (None, 128, 128,  │      3,072 │ input_layer_1[0]… │
# │ (Sequential)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_2        │ (None, 64, 64,    │    131,328 │ sequential_1[0][… │
# │ (Sequential)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_3        │ (None, 32, 32,    │    524,800 │ sequential_2[0][… │
# │ (Sequential)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_4        │ (None, 16, 16,    │  2,098,176 │ sequential_3[0][… │
# │ (Sequential)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_5        │ (None, 8, 8, 512) │  4,195,328 │ sequential_4[0][… │
# │ (Sequential)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_6        │ (None, 4, 4, 512) │  4,195,328 │ sequential_5[0][… │
# │ (Sequential)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_7        │ (None, 2, 2, 512) │  4,195,328 │ sequential_6[0][… │
# │ (Sequential)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_8        │ (None, 1, 1, 512) │  4,195,328 │ sequential_7[0][… │
# │ (Sequential)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_9        │ (None, 2, 2, 512) │  4,195,328 │ sequential_8[0][… │
# │ (Sequential)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 2, 2,      │          0 │ sequential_9[0][… │
# │ (Concatenate)       │ 1024)             │            │ sequential_7[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_10       │ (None, 4, 4, 512) │  8,389,632 │ concatenate[0][0] │
# │ (Sequential)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 4, 4,      │          0 │ sequential_10[0]… │
# │ (Concatenate)       │ 1024)             │            │ sequential_6[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_11       │ (None, 8, 8, 512) │  8,389,632 │ concatenate_1[0]… │
# │ (Sequential)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 8, 8,      │          0 │ sequential_11[0]… │
# │ (Concatenate)       │ 1024)             │            │ sequential_5[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_12       │ (None, 16, 16,    │  8,389,632 │ concatenate_2[0]… │
# │ (Sequential)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 16, 16,    │          0 │ sequential_12[0]… │
# │ (Concatenate)       │ 1024)             │            │ sequential_4[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_13       │ (None, 32, 32,    │  4,194,816 │ concatenate_3[0]… │
# │ (Sequential)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_4       │ (None, 32, 32,    │          0 │ sequential_13[0]… │
# │ (Concatenate)       │ 512)              │            │ sequential_3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_14       │ (None, 64, 64,    │  1,048,832 │ concatenate_4[0]… │
# │ (Sequential)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_5       │ (None, 64, 64,    │          0 │ sequential_14[0]… │
# │ (Concatenate)       │ 256)              │            │ sequential_2[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_15       │ (None, 128, 128,  │    262,272 │ concatenate_5[0]… │
# │ (Sequential)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_6       │ (None, 128, 128,  │          0 │ sequential_15[0]… │
# │ (Concatenate)       │ 128)              │            │ sequential_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_7  │ (None, 256, 256,  │      6,147 │ concatenate_6[0]… │
# │ (Conv2DTranspose)   │ 3)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 54,414,979 (207.58 MB)
#  Trainable params: 54,414,979 (207.58 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
print("\033[1mPhoto Generator Model Summary:\033[0m")
photo_generator.summary()
# Out:
# Photo Generator Model Summary:
# Model: "functional_34"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_17      │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_16       │ (None, 128, 128,  │      3,072 │ input_layer_17[0… │
# │ (Sequential)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_17       │ (None, 64, 64,    │    131,328 │ sequential_16[0]… │
# │ (Sequential)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_18       │ (None, 32, 32,    │    524,800 │ sequential_17[0]… │
# │ (Sequential)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_19       │ (None, 16, 16,    │  2,098,176 │ sequential_18[0]… │
# │ (Sequential)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_20       │ (None, 8, 8, 512) │  4,195,328 │ sequential_19[0]… │
# │ (Sequential)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_21       │ (None, 4, 4, 512) │  4,195,328 │ sequential_20[0]… │
# │ (Sequential)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_22       │ (None, 2, 2, 512) │  4,195,328 │ sequential_21[0]… │
# │ (Sequential)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_23       │ (None, 1, 1, 512) │  4,195,328 │ sequential_22[0]… │
# │ (Sequential)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_24       │ (None, 2, 2, 512) │  4,195,328 │ sequential_23[0]… │
# │ (Sequential)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_7       │ (None, 2, 2,      │          0 │ sequential_24[0]… │
# │ (Concatenate)       │ 1024)             │            │ sequential_22[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_25       │ (None, 4, 4, 512) │  8,389,632 │ concatenate_7[0]… │
# │ (Sequential)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_8       │ (None, 4, 4,      │          0 │ sequential_25[0]… │
# │ (Concatenate)       │ 1024)             │            │ sequential_21[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_26       │ (None, 8, 8, 512) │  8,389,632 │ concatenate_8[0]… │
# │ (Sequential)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_9       │ (None, 8, 8,      │          0 │ sequential_26[0]… │
# │ (Concatenate)       │ 1024)             │            │ sequential_20[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_27       │ (None, 16, 16,    │  8,389,632 │ concatenate_9[0]… │
# │ (Sequential)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_10      │ (None, 16, 16,    │          0 │ sequential_27[0]… │
# │ (Concatenate)       │ 1024)             │            │ sequential_19[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_28       │ (None, 32, 32,    │  4,194,816 │ concatenate_10[0… │
# │ (Sequential)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_11      │ (None, 32, 32,    │          0 │ sequential_28[0]… │
# │ (Concatenate)       │ 512)              │            │ sequential_18[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_29       │ (None, 64, 64,    │  1,048,832 │ concatenate_11[0… │
# │ (Sequential)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_12      │ (None, 64, 64,    │          0 │ sequential_29[0]… │
# │ (Concatenate)       │ 256)              │            │ sequential_17[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_30       │ (None, 128, 128,  │    262,272 │ concatenate_12[0… │
# │ (Sequential)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_13      │ (None, 128, 128,  │          0 │ sequential_30[0]… │
# │ (Concatenate)       │ 128)              │            │ sequential_16[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_15 │ (None, 256, 256,  │      6,147 │ concatenate_13[0… │
# │ (Conv2DTranspose)   │ 3)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 54,414,979 (207.58 MB)
#  Trainable params: 54,414,979 (207.58 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
print("\033[1mMonet Discriminator Model Summary:\033[0m")
monet_discriminator.summary()
# Out:
# Monet Discriminator Model Summary:
# Model: "functional_39"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_image (InputLayer)        │ (None, 256, 256, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_31 (Sequential)      │ (None, 128, 128, 64)   │         3,072 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_32 (Sequential)      │ (None, 64, 64, 128)    │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_33 (Sequential)      │ (None, 32, 32, 256)    │       524,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ zero_padding2d (ZeroPadding2D)  │ (None, 34, 34, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_19 (Conv2D)              │ (None, 31, 31, 512)    │     2,097,152 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ group_normalization_30          │ (None, 31, 31, 512)    │         1,024 │
# │ (GroupNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_19 (LeakyReLU)      │ (None, 31, 31, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ zero_padding2d_1                │ (None, 33, 33, 512)    │             0 │
# │ (ZeroPadding2D)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_20 (Conv2D)              │ (None, 30, 30, 1)      │         8,193 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,765,569 (10.55 MB)
#  Trainable params: 2,765,569 (10.55 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
print("\033[1mPhoto Discriminator Model Summary:\033[0m")
monet_discriminator.summary()
# Out:
# Photo Discriminator Model Summary:
# Model: "functional_39"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_image (InputLayer)        │ (None, 256, 256, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_31 (Sequential)      │ (None, 128, 128, 64)   │         3,072 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_32 (Sequential)      │ (None, 64, 64, 128)    │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_33 (Sequential)      │ (None, 32, 32, 256)    │       524,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ zero_padding2d (ZeroPadding2D)  │ (None, 34, 34, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_19 (Conv2D)              │ (None, 31, 31, 512)    │     2,097,152 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ group_normalization_30          │ (None, 31, 31, 512)    │         1,024 │
# │ (GroupNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_19 (LeakyReLU)      │ (None, 31, 31, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ zero_padding2d_1                │ (None, 33, 33, 512)    │             0 │
# │ (ZeroPadding2D)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_20 (Conv2D)              │ (None, 30, 30, 1)      │         8,193 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,765,569 (10.55 MB)
#  Trainable params: 2,765,569 (10.55 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### CycleGAN

# %%
class CycleGan(keras.Model):
    def __init__(
        self,
        monet_generator,
        photo_generator,
        monet_discriminator,
        photo_discriminator,
        lambda_cycle=10,
    ):
        super(CycleGan, self).__init__()
        self.m_gen = monet_generator
        self.p_gen = photo_generator
        self.m_disc = monet_discriminator
        self.p_disc = photo_discriminator
        self.lambda_cycle = lambda_cycle
        
    def compile(
        self,
        m_gen_optimizer,
        p_gen_optimizer,
        m_disc_optimizer,
        p_disc_optimizer,
        gen_loss_fn,
        disc_loss_fn,
        cycle_loss_fn,
        identity_loss_fn
    ):
        super(CycleGan, self).compile()
        self.m_gen_optimizer = m_gen_optimizer
        self.p_gen_optimizer = p_gen_optimizer
        self.m_disc_optimizer = m_disc_optimizer
        self.p_disc_optimizer = p_disc_optimizer
        self.gen_loss_fn = gen_loss_fn
        self.disc_loss_fn = disc_loss_fn
        self.cycle_loss_fn = cycle_loss_fn
        self.identity_loss_fn = identity_loss_fn
        
    def train_step(self, batch_data):
        real_monet, real_photo = batch_data
        
        with tf.GradientTape(persistent=True) as tape:
            # photo to monet back to photo
            fake_monet = self.m_gen(real_photo, training=True)
            cycled_photo = self.p_gen(fake_monet, training=True)

            # monet to photo back to monet
            fake_photo = self.p_gen(real_monet, training=True)
            cycled_monet = self.m_gen(fake_photo, training=True)

            # generating itself
            same_monet = self.m_gen(real_monet, training=True)
            same_photo = self.p_gen(real_photo, training=True)

            # discriminator used to check, inputing real images
            disc_real_monet = self.m_disc(real_monet, training=True)
            disc_real_photo = self.p_disc(real_photo, training=True)

            # discriminator used to check, inputing fake images
            disc_fake_monet = self.m_disc(fake_monet, training=True)
            disc_fake_photo = self.p_disc(fake_photo, training=True)

            # evaluates generator loss
            monet_gen_loss = self.gen_loss_fn(disc_fake_monet)
            photo_gen_loss = self.gen_loss_fn(disc_fake_photo)

            # evaluates total cycle consistency loss
            total_cycle_loss = self.cycle_loss_fn(real_monet, cycled_monet, self.lambda_cycle) + self.cycle_loss_fn(real_photo, cycled_photo, self.lambda_cycle)

            # evaluates total generator loss
            total_monet_gen_loss = monet_gen_loss + total_cycle_loss + self.identity_loss_fn(real_monet, same_monet, self.lambda_cycle)
            total_photo_gen_loss = photo_gen_loss + total_cycle_loss + self.identity_loss_fn(real_photo, same_photo, self.lambda_cycle)

            # evaluates discriminator loss
            monet_disc_loss = self.disc_loss_fn(disc_real_monet, disc_fake_monet)
            photo_disc_loss = self.disc_loss_fn(disc_real_photo, disc_fake_photo)

        # Calculate the gradients for generator and discriminator
        monet_generator_gradients = tape.gradient(total_monet_gen_loss,
                                                  self.m_gen.trainable_variables)
        photo_generator_gradients = tape.gradient(total_photo_gen_loss,
                                                  self.p_gen.trainable_variables)

        monet_discriminator_gradients = tape.gradient(monet_disc_loss,
                                                      self.m_disc.trainable_variables)
        photo_discriminator_gradients = tape.gradient(photo_disc_loss,
                                                      self.p_disc.trainable_variables)

        # Apply the gradients to the optimizer
        self.m_gen_optimizer.apply_gradients(zip(monet_generator_gradients,
                                                 self.m_gen.trainable_variables))

        self.p_gen_optimizer.apply_gradients(zip(photo_generator_gradients,
                                                 self.p_gen.trainable_variables))

        self.m_disc_optimizer.apply_gradients(zip(monet_discriminator_gradients,
                                                  self.m_disc.trainable_variables))

        self.p_disc_optimizer.apply_gradients(zip(photo_discriminator_gradients,
                                                  self.p_disc.trainable_variables))
        
        return {
            "monet_gen_loss": total_monet_gen_loss,
            "photo_gen_loss": total_photo_gen_loss,
            "monet_disc_loss": monet_disc_loss,
            "photo_disc_loss": photo_disc_loss
        }

# %% [markdown]
# ### Loss Functions

# %%
with strategy.scope():
    def discriminator_loss(real, generated):
        if LOSS_TYPE == 'bce':
            real_loss = tf.keras.losses.BinaryCrossentropy(from_logits=True, reduction=tf.keras.losses.Reduction.NONE)(tf.ones_like(real), real)

            generated_loss = tf.keras.losses.BinaryCrossentropy(from_logits=True, reduction=tf.keras.losses.Reduction.NONE)(tf.zeros_like(generated), generated)
        
        elif LOSS_TYPE == 'mse':
            real_loss = tf.keras.losses.MeanSquaredError()(tf.ones_like(real), real)

            generated_loss = tf.keras.losses.MeanSquaredError()(tf.zeros_like(generated), generated)

        total_disc_loss = real_loss + generated_loss

        return total_disc_loss * 0.5


with strategy.scope():
    def generator_loss(generated):
        if LOSS_TYPE == 'bce':
            return tf.keras.losses.BinaryCrossentropy(from_logits=True, reduction=tf.keras.losses.Reduction.NONE)(tf.ones_like(generated), generated)
        elif LOSS_TYPE == 'mse':
            return tf.keras.losses.MeanSquaredError()(tf.ones_like(generated), generated)
   
    

with strategy.scope():
    def calc_cycle_loss(real_image, cycled_image, LAMBDA):
        loss1 = tf.reduce_mean(tf.abs(real_image - cycled_image))

        return LAMBDA * loss1


with strategy.scope():
    def identity_loss(real_image, same_image, LAMBDA):
        loss = tf.reduce_mean(tf.abs(real_image - same_image))
        return LAMBDA * 0.5 * loss

# %% [markdown]
# ### Compile Model

# %%
with strategy.scope():
    monet_generator_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)
    photo_generator_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)

    monet_discriminator_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)
    photo_discriminator_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)


with strategy.scope():
    cycle_gan_model = CycleGan(
        monet_generator, photo_generator, monet_discriminator, photo_discriminator
    )

    cycle_gan_model.compile(
        m_gen_optimizer = monet_generator_optimizer,
        p_gen_optimizer = photo_generator_optimizer,
        m_disc_optimizer = monet_discriminator_optimizer,
        p_disc_optimizer = photo_discriminator_optimizer,
        gen_loss_fn = generator_loss,
        disc_loss_fn = discriminator_loss,
        cycle_loss_fn = calc_cycle_loss,
        identity_loss_fn = identity_loss
    )

# %%
print("\033[1mCycleGAN Model Summary:\033[0m")
cycle_gan_model.summary()
# Out:
# CycleGAN Model Summary:
# Model: "cycle_gan"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ functional_17 (Functional)      │ ?                      │    54,414,979 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ functional_34 (Functional)      │ ?                      │    54,414,979 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ functional_39 (Functional)      │ ?                      │     2,765,569 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ functional_44 (Functional)      │ ?                      │     2,765,569 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 114,361,096 (436.25 MB)
#  Trainable params: 114,361,096 (436.25 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ---

# %% [markdown]
# ## Train CycleGAN Model

# %%
# Set up checkpoint callback
checkpoint_path = 'checkpoints/'
checkpoint_name = 'cp-{epoch:04d}.weights.h5'
filepath = checkpoint_path + checkpoint_name
checkpoint_callback = ModelCheckpoint(
    filepath=filepath,
    verbose=0,
    save_weights_only=True,
    save_freq=3000) # Save CKPT every 10 epochs (1 epoch = 300 batches)

# %%
history = cycle_gan_model.fit(
    tf.data.Dataset.zip((monet_ds, photo_ds)),
    epochs=EPOCHS,
    callbacks = [checkpoint_callback]
)
# Out:
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1709609180.553371      72 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 163s 151ms/step - monet_disc_loss: 0.6587 - monet_gen_loss: 5.1253 - photo_disc_loss: 0.6303 - photo_gen_loss: 5.3422 - loss: 0.0000e+00
# Epoch 2/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 151ms/step - monet_disc_loss: 0.6640 - monet_gen_loss: 3.5985 - photo_disc_loss: 0.6407 - photo_gen_loss: 3.7043 - loss: 0.0000e+00
# Epoch 3/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 47s 151ms/step - monet_disc_loss: 0.6545 - monet_gen_loss: 3.5080 - photo_disc_loss: 0.6368 - photo_gen_loss: 3.6066 - loss: 0.0000e+00
# Epoch 4/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 151ms/step - monet_disc_loss: 0.6478 - monet_gen_loss: 3.3307 - photo_disc_loss: 0.6341 - photo_gen_loss: 3.3996 - loss: 0.0000e+00
# Epoch 5/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 151ms/step - monet_disc_loss: 0.6397 - monet_gen_loss: 3.1826 - photo_disc_loss: 0.6247 - photo_gen_loss: 3.2650 - loss: 0.0000e+00
# Epoch 6/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 151ms/step - monet_disc_loss: 0.6307 - monet_gen_loss: 3.0958 - photo_disc_loss: 0.6160 - photo_gen_loss: 3.1749 - loss: 0.0000e+00
# Epoch 7/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 82s 151ms/step - monet_disc_loss: 0.6226 - monet_gen_loss: 3.0736 - photo_disc_loss: 0.6191 - photo_gen_loss: 3.1250 - loss: 0.0000e+00
# Epoch 8/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 150ms/step - monet_disc_loss: 0.6172 - monet_gen_loss: 3.0790 - photo_disc_loss: 0.6112 - photo_gen_loss: 3.1289 - loss: 0.0000e+00
# Epoch 9/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 150ms/step - monet_disc_loss: 0.6154 - monet_gen_loss: 3.0842 - photo_disc_loss: 0.5957 - photo_gen_loss: 3.1691 - loss: 0.0000e+00
# Epoch 10/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 49s 159ms/step - monet_disc_loss: 0.6084 - monet_gen_loss: 3.0708 - photo_disc_loss: 0.6031 - photo_gen_loss: 3.1585 - loss: 0.0000e+00
# Epoch 11/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 151ms/step - monet_disc_loss: 0.6141 - monet_gen_loss: 3.0505 - photo_disc_loss: 0.6095 - photo_gen_loss: 3.1144 - loss: 0.0000e+00
# Epoch 12/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 151ms/step - monet_disc_loss: 0.6179 - monet_gen_loss: 3.0218 - photo_disc_loss: 0.6151 - photo_gen_loss: 3.0699 - loss: 0.0000e+00
# Epoch 13/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 150ms/step - monet_disc_loss: 0.6136 - monet_gen_loss: 2.9843 - photo_disc_loss: 0.6115 - photo_gen_loss: 3.0416 - loss: 0.0000e+00
# Epoch 14/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 151ms/step - monet_disc_loss: 0.6122 - monet_gen_loss: 2.9565 - photo_disc_loss: 0.6130 - photo_gen_loss: 3.0031 - loss: 0.0000e+00
# Epoch 15/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 151ms/step - monet_disc_loss: 0.6101 - monet_gen_loss: 2.9260 - photo_disc_loss: 0.6166 - photo_gen_loss: 2.9591 - loss: 0.0000e+00
# Epoch 16/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 150ms/step - monet_disc_loss: 0.6082 - monet_gen_loss: 2.8903 - photo_disc_loss: 0.6161 - photo_gen_loss: 2.9194 - loss: 0.0000e+00
# Epoch 17/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 150ms/step - monet_disc_loss: 0.6105 - monet_gen_loss: 2.8603 - photo_disc_loss: 0.6172 - photo_gen_loss: 2.8870 - loss: 0.0000e+00
# Epoch 18/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 150ms/step - monet_disc_loss: 0.6107 - monet_gen_loss: 2.8489 - photo_disc_loss: 0.6119 - photo_gen_loss: 2.8852 - loss: 0.0000e+00
# Epoch 19/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 150ms/step - monet_disc_loss: 0.6117 - monet_gen_loss: 2.8217 - photo_disc_loss: 0.6149 - photo_gen_loss: 2.8561 - loss: 0.0000e+00
# Epoch 20/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 48s 158ms/step - monet_disc_loss: 0.6120 - monet_gen_loss: 2.8000 - photo_disc_loss: 0.6134 - photo_gen_loss: 2.8335 - loss: 0.0000e+00
# Epoch 21/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 151ms/step - monet_disc_loss: 0.6130 - monet_gen_loss: 2.7976 - photo_disc_loss: 0.6131 - photo_gen_loss: 2.8295 - loss: 0.0000e+00
# Epoch 22/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 150ms/step - monet_disc_loss: 0.6185 - monet_gen_loss: 2.7558 - photo_disc_loss: 0.6147 - photo_gen_loss: 2.7946 - loss: 0.0000e+00
# Epoch 23/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 150ms/step - monet_disc_loss: 0.6186 - monet_gen_loss: 2.7359 - photo_disc_loss: 0.6150 - photo_gen_loss: 2.7746 - loss: 0.0000e+00
# Epoch 24/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 150ms/step - monet_disc_loss: 0.6186 - monet_gen_loss: 2.7226 - photo_disc_loss: 0.6103 - photo_gen_loss: 2.7546 - loss: 0.0000e+00
# Epoch 25/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 150ms/step - monet_disc_loss: 0.6203 - monet_gen_loss: 2.6857 - photo_disc_loss: 0.6085 - photo_gen_loss: 2.7340 - loss: 0.0000e+00
# Epoch 26/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 151ms/step - monet_disc_loss: 0.6219 - monet_gen_loss: 2.6583 - photo_disc_loss: 0.6074 - photo_gen_loss: 2.7072 - loss: 0.0000e+00
# Epoch 27/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 150ms/step - monet_disc_loss: 0.6178 - monet_gen_loss: 2.6574 - photo_disc_loss: 0.6073 - photo_gen_loss: 2.6924 - loss: 0.0000e+00
# Epoch 28/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 150ms/step - monet_disc_loss: 0.6178 - monet_gen_loss: 2.6432 - photo_disc_loss: 0.6065 - photo_gen_loss: 2.6885 - loss: 0.0000e+00
# Epoch 29/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 150ms/step - monet_disc_loss: 0.6189 - monet_gen_loss: 2.6262 - photo_disc_loss: 0.6029 - photo_gen_loss: 2.6721 - loss: 0.0000e+00
# Epoch 30/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 49s 159ms/step - monet_disc_loss: 0.6269 - monet_gen_loss: 2.6139 - photo_disc_loss: 0.6089 - photo_gen_loss: 2.6740 - loss: 0.0000e+00
# Epoch 31/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 151ms/step - monet_disc_loss: 0.6243 - monet_gen_loss: 2.5992 - photo_disc_loss: 0.6096 - photo_gen_loss: 2.6533 - loss: 0.0000e+00
# Epoch 32/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 150ms/step - monet_disc_loss: 0.6223 - monet_gen_loss: 2.5963 - photo_disc_loss: 0.6039 - photo_gen_loss: 2.6705 - loss: 0.0000e+00
# Epoch 33/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 150ms/step - monet_disc_loss: 0.6251 - monet_gen_loss: 2.5821 - photo_disc_loss: 0.6090 - photo_gen_loss: 2.6496 - loss: 0.0000e+00
# Epoch 34/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 150ms/step - monet_disc_loss: 0.6194 - monet_gen_loss: 2.6036 - photo_disc_loss: 0.6027 - photo_gen_loss: 2.6640 - loss: 0.0000e+00
# Epoch 35/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 151ms/step - monet_disc_loss: 0.6247 - monet_gen_loss: 2.5896 - photo_disc_loss: 0.6057 - photo_gen_loss: 2.6576 - loss: 0.0000e+00
# Epoch 36/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 150ms/step - monet_disc_loss: 0.6287 - monet_gen_loss: 2.5593 - photo_disc_loss: 0.6082 - photo_gen_loss: 2.6411 - loss: 0.0000e+00
# Epoch 37/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 150ms/step - monet_disc_loss: 0.6281 - monet_gen_loss: 2.5594 - photo_disc_loss: 0.6109 - photo_gen_loss: 2.6488 - loss: 0.0000e+00
# Epoch 38/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 150ms/step - monet_disc_loss: 0.6169 - monet_gen_loss: 2.5950 - photo_disc_loss: 0.6024 - photo_gen_loss: 2.6657 - loss: 0.0000e+00
# Epoch 39/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 150ms/step - monet_disc_loss: 0.6295 - monet_gen_loss: 2.5583 - photo_disc_loss: 0.6117 - photo_gen_loss: 2.6416 - loss: 0.0000e+00
# Epoch 40/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 48s 158ms/step - monet_disc_loss: 0.6278 - monet_gen_loss: 2.5449 - photo_disc_loss: 0.6075 - photo_gen_loss: 2.6359 - loss: 0.0000e+00
# Epoch 41/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 151ms/step - monet_disc_loss: 0.6242 - monet_gen_loss: 2.5887 - photo_disc_loss: 0.5977 - photo_gen_loss: 2.6843 - loss: 0.0000e+00
# Epoch 42/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 150ms/step - monet_disc_loss: 0.6306 - monet_gen_loss: 2.5439 - photo_disc_loss: 0.6057 - photo_gen_loss: 2.6384 - loss: 0.0000e+00
# Epoch 43/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 150ms/step - monet_disc_loss: 0.6283 - monet_gen_loss: 2.5319 - photo_disc_loss: 0.6035 - photo_gen_loss: 2.6512 - loss: 0.0000e+00
# Epoch 44/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 150ms/step - monet_disc_loss: 0.6321 - monet_gen_loss: 2.5369 - photo_disc_loss: 0.6009 - photo_gen_loss: 2.6538 - loss: 0.0000e+00
# Epoch 45/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 151ms/step - monet_disc_loss: 0.6289 - monet_gen_loss: 2.5375 - photo_disc_loss: 0.6045 - photo_gen_loss: 2.6381 - loss: 0.0000e+00
# Epoch 46/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 150ms/step - monet_disc_loss: 0.6245 - monet_gen_loss: 2.5301 - photo_disc_loss: 0.6018 - photo_gen_loss: 2.6179 - loss: 0.0000e+00
# Epoch 47/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 150ms/step - monet_disc_loss: 0.6328 - monet_gen_loss: 2.4840 - photo_disc_loss: 0.6098 - photo_gen_loss: 2.5880 - loss: 0.0000e+00
# Epoch 48/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 151ms/step - monet_disc_loss: 0.6270 - monet_gen_loss: 2.5143 - photo_disc_loss: 0.6067 - photo_gen_loss: 2.6211 - loss: 0.0000e+00
# Epoch 49/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 151ms/step - monet_disc_loss: 0.6246 - monet_gen_loss: 2.5362 - photo_disc_loss: 0.5822 - photo_gen_loss: 2.7059 - loss: 0.0000e+00
# Epoch 50/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 49s 158ms/step - monet_disc_loss: 0.6256 - monet_gen_loss: 2.5208 - photo_disc_loss: 0.5925 - photo_gen_loss: 2.6577 - loss: 0.0000e+00
# Epoch 51/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 151ms/step - monet_disc_loss: 0.6267 - monet_gen_loss: 2.5286 - photo_disc_loss: 0.5908 - photo_gen_loss: 2.6534 - loss: 0.0000e+00
# Epoch 52/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 150ms/step - monet_disc_loss: 0.6304 - monet_gen_loss: 2.5107 - photo_disc_loss: 0.6072 - photo_gen_loss: 2.6390 - loss: 0.0000e+00
# Epoch 53/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 150ms/step - monet_disc_loss: 0.6216 - monet_gen_loss: 2.5903 - photo_disc_loss: 0.5837 - photo_gen_loss: 2.7634 - loss: 0.0000e+00
# Epoch 54/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 150ms/step - monet_disc_loss: 0.6267 - monet_gen_loss: 2.5066 - photo_disc_loss: 0.5908 - photo_gen_loss: 2.6500 - loss: 0.0000e+00
# Epoch 55/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 150ms/step - monet_disc_loss: 0.6244 - monet_gen_loss: 2.5195 - photo_disc_loss: 0.6055 - photo_gen_loss: 2.6179 - loss: 0.0000e+00
# Epoch 56/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 150ms/step - monet_disc_loss: 0.6237 - monet_gen_loss: 2.5087 - photo_disc_loss: 0.5826 - photo_gen_loss: 2.6563 - loss: 0.0000e+00
# Epoch 57/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 150ms/step - monet_disc_loss: 0.6294 - monet_gen_loss: 2.4996 - photo_disc_loss: 0.5967 - photo_gen_loss: 2.6184 - loss: 0.0000e+00
# Epoch 58/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 150ms/step - monet_disc_loss: 0.6309 - monet_gen_loss: 2.4799 - photo_disc_loss: 0.5935 - photo_gen_loss: 2.6087 - loss: 0.0000e+00
# Epoch 59/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 150ms/step - monet_disc_loss: 0.6150 - monet_gen_loss: 2.5333 - photo_disc_loss: 0.5573 - photo_gen_loss: 2.7180 - loss: 0.0000e+00
# Epoch 60/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 48s 158ms/step - monet_disc_loss: 0.6189 - monet_gen_loss: 2.6016 - photo_disc_loss: 0.5634 - photo_gen_loss: 2.8114 - loss: 0.0000e+00
# Epoch 61/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 150ms/step - monet_disc_loss: 0.6263 - monet_gen_loss: 2.5045 - photo_disc_loss: 0.5914 - photo_gen_loss: 2.6576 - loss: 0.0000e+00
# Epoch 62/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 150ms/step - monet_disc_loss: 0.6242 - monet_gen_loss: 2.5346 - photo_disc_loss: 0.5816 - photo_gen_loss: 2.7106 - loss: 0.0000e+00
# Epoch 63/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 151ms/step - monet_disc_loss: 0.6214 - monet_gen_loss: 2.5030 - photo_disc_loss: 0.5797 - photo_gen_loss: 2.6557 - loss: 0.0000e+00
# Epoch 64/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 150ms/step - monet_disc_loss: 0.6215 - monet_gen_loss: 2.4912 - photo_disc_loss: 0.5929 - photo_gen_loss: 2.6347 - loss: 0.0000e+00
# Epoch 65/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 150ms/step - monet_disc_loss: 0.6171 - monet_gen_loss: 2.4946 - photo_disc_loss: 0.5851 - photo_gen_loss: 2.6349 - loss: 0.0000e+00
# Epoch 66/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 150ms/step - monet_disc_loss: 0.6183 - monet_gen_loss: 2.5054 - photo_disc_loss: 0.5756 - photo_gen_loss: 2.6558 - loss: 0.0000e+00
# Epoch 67/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 150ms/step - monet_disc_loss: 0.6131 - monet_gen_loss: 2.5655 - photo_disc_loss: 0.5797 - photo_gen_loss: 2.7087 - loss: 0.0000e+00
# Epoch 68/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 150ms/step - monet_disc_loss: 0.6146 - monet_gen_loss: 2.5533 - photo_disc_loss: 0.5872 - photo_gen_loss: 2.6761 - loss: 0.0000e+00
# Epoch 69/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 150ms/step - monet_disc_loss: 0.6265 - monet_gen_loss: 2.4641 - photo_disc_loss: 0.5935 - photo_gen_loss: 2.6004 - loss: 0.0000e+00
# Epoch 70/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 49s 158ms/step - monet_disc_loss: 0.6179 - monet_gen_loss: 2.4872 - photo_disc_loss: 0.5804 - photo_gen_loss: 2.6340 - loss: 0.0000e+00
# Epoch 71/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 150ms/step - monet_disc_loss: 0.6152 - monet_gen_loss: 2.4926 - photo_disc_loss: 0.5846 - photo_gen_loss: 2.6278 - loss: 0.0000e+00
# Epoch 72/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 150ms/step - monet_disc_loss: 0.6157 - monet_gen_loss: 2.4983 - photo_disc_loss: 0.5796 - photo_gen_loss: 2.6597 - loss: 0.0000e+00
# Epoch 73/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 150ms/step - monet_disc_loss: 0.5970 - monet_gen_loss: 2.5992 - photo_disc_loss: 0.5562 - photo_gen_loss: 2.7849 - loss: 0.0000e+00
# Epoch 74/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 150ms/step - monet_disc_loss: 0.6119 - monet_gen_loss: 2.5160 - photo_disc_loss: 0.5814 - photo_gen_loss: 2.6496 - loss: 0.0000e+00
# Epoch 75/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 150ms/step - monet_disc_loss: 0.6062 - monet_gen_loss: 2.5042 - photo_disc_loss: 0.5759 - photo_gen_loss: 2.6412 - loss: 0.0000e+00
# Epoch 76/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 150ms/step - monet_disc_loss: 0.6090 - monet_gen_loss: 2.5090 - photo_disc_loss: 0.5829 - photo_gen_loss: 2.6381 - loss: 0.0000e+00
# Epoch 77/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 150ms/step - monet_disc_loss: 0.6020 - monet_gen_loss: 2.5344 - photo_disc_loss: 0.5553 - photo_gen_loss: 2.6880 - loss: 0.0000e+00
# Epoch 78/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 150ms/step - monet_disc_loss: 0.5895 - monet_gen_loss: 2.6446 - photo_disc_loss: 0.5617 - photo_gen_loss: 2.8804 - loss: 0.0000e+00
# Epoch 79/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 150ms/step - monet_disc_loss: 0.6077 - monet_gen_loss: 2.5483 - photo_disc_loss: 0.5788 - photo_gen_loss: 2.6914 - loss: 0.0000e+00
# Epoch 80/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 48s 158ms/step - monet_disc_loss: 0.6032 - monet_gen_loss: 2.5531 - photo_disc_loss: 0.5684 - photo_gen_loss: 2.6798 - loss: 0.0000e+00
# Epoch 81/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 150ms/step - monet_disc_loss: 0.5965 - monet_gen_loss: 2.5826 - photo_disc_loss: 0.5504 - photo_gen_loss: 2.7654 - loss: 0.0000e+00
# Epoch 82/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 150ms/step - monet_disc_loss: 0.5966 - monet_gen_loss: 2.5923 - photo_disc_loss: 0.5706 - photo_gen_loss: 2.7097 - loss: 0.0000e+00
# Epoch 83/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 150ms/step - monet_disc_loss: 0.5804 - monet_gen_loss: 2.6503 - photo_disc_loss: 0.5579 - photo_gen_loss: 2.7617 - loss: 0.0000e+00
# Epoch 84/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 150ms/step - monet_disc_loss: 0.5840 - monet_gen_loss: 2.7001 - photo_disc_loss: 0.5332 - photo_gen_loss: 2.9073 - loss: 0.0000e+00
# Epoch 85/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 151ms/step - monet_disc_loss: 0.5956 - monet_gen_loss: 2.5751 - photo_disc_loss: 0.5570 - photo_gen_loss: 2.7289 - loss: 0.0000e+00
# Epoch 86/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 151ms/step - monet_disc_loss: 0.5919 - monet_gen_loss: 2.5680 - photo_disc_loss: 0.5671 - photo_gen_loss: 2.6888 - loss: 0.0000e+00
# Epoch 87/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 150ms/step - monet_disc_loss: 0.5892 - monet_gen_loss: 2.5907 - photo_disc_loss: 0.5691 - photo_gen_loss: 2.7063 - loss: 0.0000e+00
# Epoch 88/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 150ms/step - monet_disc_loss: 0.5949 - monet_gen_loss: 2.5759 - photo_disc_loss: 0.5659 - photo_gen_loss: 2.6826 - loss: 0.0000e+00
# Epoch 89/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 150ms/step - monet_disc_loss: 0.5892 - monet_gen_loss: 2.5961 - photo_disc_loss: 0.5610 - photo_gen_loss: 2.6976 - loss: 0.0000e+00
# Epoch 90/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 48s 158ms/step - monet_disc_loss: 0.5914 - monet_gen_loss: 2.5928 - photo_disc_loss: 0.5631 - photo_gen_loss: 2.7211 - loss: 0.0000e+00
# Epoch 91/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 151ms/step - monet_disc_loss: 0.5873 - monet_gen_loss: 2.5650 - photo_disc_loss: 0.5672 - photo_gen_loss: 2.6777 - loss: 0.0000e+00
# Epoch 92/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 150ms/step - monet_disc_loss: 0.5810 - monet_gen_loss: 2.6471 - photo_disc_loss: 0.5395 - photo_gen_loss: 2.8120 - loss: 0.0000e+00
# Epoch 93/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 150ms/step - monet_disc_loss: 0.5848 - monet_gen_loss: 2.6636 - photo_disc_loss: 0.5618 - photo_gen_loss: 2.7328 - loss: 0.0000e+00
# Epoch 94/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 150ms/step - monet_disc_loss: 0.5761 - monet_gen_loss: 2.6517 - photo_disc_loss: 0.5680 - photo_gen_loss: 2.7492 - loss: 0.0000e+00
# Epoch 95/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 150ms/step - monet_disc_loss: 0.5480 - monet_gen_loss: 2.7130 - photo_disc_loss: 0.5065 - photo_gen_loss: 2.8382 - loss: 0.0000e+00
# Epoch 96/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 150ms/step - monet_disc_loss: 0.5678 - monet_gen_loss: 2.9084 - photo_disc_loss: 0.4931 - photo_gen_loss: 3.1846 - loss: 0.0000e+00
# Epoch 97/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 151ms/step - monet_disc_loss: 0.5825 - monet_gen_loss: 2.6419 - photo_disc_loss: 0.5583 - photo_gen_loss: 2.7978 - loss: 0.0000e+00
# Epoch 98/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 150ms/step - monet_disc_loss: 0.5857 - monet_gen_loss: 2.6303 - photo_disc_loss: 0.5531 - photo_gen_loss: 2.7585 - loss: 0.0000e+00
# Epoch 99/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 46s 150ms/step - monet_disc_loss: 0.5876 - monet_gen_loss: 2.6928 - photo_disc_loss: 0.5515 - photo_gen_loss: 2.7883 - loss: 0.0000e+00
# Epoch 100/100
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 48s 158ms/step - monet_disc_loss: 0.5818 - monet_gen_loss: 2.6365 - photo_disc_loss: 0.5423 - photo_gen_loss: 2.8034 - loss: 0.0000e+00

# %%
if not os.path.exists('/kaggle/working/checkpoints'):
    os.makedirs('/kaggle/working/checkpoints')

# %%
cycle_gan_model.save_weights(f'/kaggle/working/checkpoints/{MODEL_NAME}_gan.weights.h5')

# %% [markdown]
# ---

# %% [markdown]
# ## Visualize Results

# %%
_, ax = plt.subplots(5, 2, figsize=(12, 24))
for i, img in enumerate(photo_original_ds.take(5)):
    prediction = monet_generator(img, training=False)[0].numpy()
    prediction = (prediction * 127.5 + 127.5).astype(np.uint8)
    img = (img[0] * 127.5 + 127.5).numpy().astype(np.uint8)

    ax[i, 0].imshow(img)
    ax[i, 1].imshow(prediction)
    ax[i, 0].set_title("Input Photo")
    ax[i, 1].set_title("Monet-esque")
    ax[i, 0].axis("off")
    ax[i, 1].axis("off")
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## Create Kaggle Submission File

# %%
if not os.path.exists('../images'):
    os.makedirs('../images')

# %%
i = 1
for img in photo_original_ds:
    prediction = monet_generator(img, training=False)[0].numpy()
    prediction = (prediction * 127.5 + 127.5).astype(np.uint8)
    im = PIL.Image.fromarray(prediction)
    im.save(f"../images/" + str(i) + ".jpg")
    i += 1

shutil.make_archive(f"/kaggle/working/images", 'zip', "/kaggle/images")
# Out:
# '/kaggle/working/images.zip'

# %% [markdown]
# ---
